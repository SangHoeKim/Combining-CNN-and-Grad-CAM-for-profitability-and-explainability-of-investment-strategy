# %%
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

from time import time
from pathlib import Path
import sys, os
from tqdm.auto import tqdm

import datetime
import numpy as np
import pandas as pd
import random

from sklearn.preprocessing import MinMaxScaler, RobustScaler, StandardScaler
from scipy.stats import spearmanr
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import SMOTE, RandomOverSampler

import torch
from torch.utils.data import TensorDataset, DataLoader

from pytorch_grad_cam import GradCAM, ScoreCAM, GradCAMPlusPlus, AblationCAM, XGradCAM, EigenCAM
from pytorch_grad_cam.utils.image import show_cam_on_image
from pytorch_grad_cam.utils.model_targets import ClassifierOutputTarget

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, f1_score
from sklearn.model_selection import train_test_split

np.set_printoptions(precision=3, suppress=True)

# pakage for study
from utils import *

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

torch.manual_seed(777)

print(device)
# Out:
# cuda

# %%
data_raw = pd.read_csv("data/2.kospi200futures_clustered.csv")
data_raw.date = pd.to_datetime(data_raw.date, format='%Y%m%d')
data_raw = data_raw.set_index(['date','time'])

drop_cols = ["1_updown", "5_updown", "21_updown", "close"]
target = "1_updown"

data = data_raw.dropna()

date_list = list(data.index.get_level_values("date").unique())

# %%
test_num = 26*5

date = datetime.datetime.strptime("2021-12-20", "%Y-%m-%d")
test_start_dates = [date]

for n in range(1,test_num):
    date = date - datetime.timedelta(days=14)
    test_start_dates.append(date)
    
test_start_dates = test_start_dates[::-1]

# %%
random.seed(907)

valid_size = 14
test_size = 14
    
batch_size = 64
n_epochs = 1000
T_max = n_epochs / 100

start_lr = 0.001
min_lr = 0.00001

# early stopping patience;
# how long to wait since the last time the validation loss improved
patience = 20
view_time = 4

feature_list = [x.split('_')[-1] for x in data.columns[:16]]
columns_list = data.drop(drop_cols, axis=1).columns
num_list = [x.split('_')[0] for x in columns_list[::16]]

# train months
train_n = 18
train_size = 30 * train_n

# %%
# %%time

test_df = pd.DataFrame()
importance_0 = pd.DataFrame(columns=columns_list)
importance_1 = pd.DataFrame(columns=columns_list)
count_df = pd.DataFrame(columns=['count'])

valid_true_all = []
valid_pred_all = []
test_true_all = []
test_pred_all = []

count = 1
total_count = 26
for test_start in tqdm(test_start_dates[-total_count:]):
    
    print(f"{count}/{total_count} {test_start.strftime('%Y-%m-%d')} training start")
    
    train_data, valid_data, test_data = make_rolling(data, test_start, test_size, valid_size=valid_size, train_size=train_size)

    # Generate dataset
    train_X = train_data.drop(drop_cols, axis=1)
    train_y = train_data[target]

    valid_X = valid_data.drop(drop_cols, axis=1)
    valid_y = valid_data[target]

    test_X = test_data.drop(drop_cols,axis=1)
    test_y = test_data[target]

    test_indexs = test_data.index

    # Scaler
    scaler = RobustScaler()
    scaler.fit(train_X)

    train_X = scaler.transform(train_X)
    valid_X = scaler.transform(valid_X)
    test_X = scaler.transform(test_X)

    # SMOTE over sample for validation dataset
    smote = SMOTE(random_state=0, )
    randomoversampling = RandomOverSampler(random_state=0)
    try:
        valid_X_SMOTE, valid_y_SMOTE = smote.fit_resample(valid_X, valid_y)
    except:
        valid_X_SMOTE, valid_y_SMOTE = randomoversampling.fit_resample(valid_X, valid_y)

    # Reshape
    train_X = train_X.reshape(-1, 1, 16, 16)
    valid_X_SMOTE = valid_X_SMOTE.reshape(-1, 1, 16, 16)
    test_X = test_X.reshape(-1, 1, 16, 16)

    # convert to tensor
    train_X_tensor = torch.FloatTensor(train_X).to(device)
    train_y_tensor = torch.LongTensor(train_y.values).to(device)

    valid_X_tensor = torch.FloatTensor(valid_X_SMOTE).to(device)
    valid_y_tensor = torch.LongTensor(valid_y_SMOTE.values).to(device)

    test_X_tensor = torch.FloatTensor(test_X).to(device)
    test_y_tensor = torch.LongTensor(test_y.values).to(device)

    model = CNN(output_size=2).to(device)
    model.apply(weight_init_uniform)

    # loss & optimizer setting
    criterion = torch.nn.CrossEntropyLoss().to(device)

    optimizer = torch.optim.Adam(model.parameters(), lr=start_lr)
    scheduler = get_scheduler(optimizer, T_max, min_lr)

    # make dataset and dataloader
    train_dataset = TensorDataset(train_X_tensor, train_y_tensor)
    valid_dataset = TensorDataset(valid_X_tensor, valid_y_tensor)

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=True)

    model, train_loss, valid_loss = train_model(model, train_loader, valid_loader, optimizer, criterion, patience, n_epochs, view_time=view_time)

    # predict
    model = model.cpu()

    # set datasets
    train_X_tensor = train_X_tensor.to("cpu")
    train_y_tensor = train_y_tensor.to("cpu")

    valid_X = valid_X.reshape(-1, 1, 16, 16)
    valid_X_tensor = torch.FloatTensor(valid_X)
    valid_y_tensor = torch.LongTensor(valid_y.values)

    test_X_tensor = test_X_tensor.to("cpu")
    test_y_tensor = test_y_tensor.to("cpu")

    # predict
    train_y_pred = model(train_X_tensor).argmax(axis=1).tolist()
    valid_y_pred = model(valid_X_tensor).argmax(axis=1).tolist()
    test_y_pred = model(test_X_tensor).argmax(axis=1).tolist()

    valid_true_all += valid_y.to_list()
    valid_pred_all += valid_y_pred
    test_true_all += test_y.to_list()
    test_pred_all += test_y_pred

    test_df_temp = test_y.to_frame()
    test_df_temp['pred'] = test_y_pred
    test_df_temp['count'] = count

    test_df = pd.concat([test_df, test_df_temp])

    # average of correct answers

    target_layers = model.cnn_layer
    cam = GradCAM(model=model, target_layers=target_layers)

    correct_idx = [i for i, x in enumerate(np.array(valid_y) == np.array(valid_y_pred)) if x]
    np.random.seed(907)

    answer_0 = []
    answer_1 = []

    for num in correct_idx:
        answer = int(valid_y[num])
        X = torch.FloatTensor(valid_X[num])
        label = int(valid_y_pred[num])

        if answer == 0:
            # You can also pass aug_smooth=True and eigen_smooth=True, to apply smoothing.
            grayscale_cam = cam(input_tensor=X.unsqueeze(0), targets=[ClassifierOutputTarget(0)])
            # In this example grayscale_cam has only one image in the batch:
            grayscale_cam = grayscale_cam[0, :]

            answer_0.append(grayscale_cam)

        else:
            # You can also pass aug_smooth=True and eigen_smooth=True, to apply smoothing.
            grayscale_cam = cam(input_tensor=X.unsqueeze(0), targets=[ClassifierOutputTarget(1)])
            # In this example grayscale_cam has only one image in the batch:
            grayscale_cam = grayscale_cam[0, :]

            answer_1.append(grayscale_cam)

    idx = test_start.strftime('%Y-%m-%d')

    try:
        importance_0.loc[idx] = np.mean(answer_0, axis=0).reshape(-1)

    except:
        importance_0.loc[idx] = 0

    try:
        importance_1.loc[idx] = np.mean(answer_1, axis=0).reshape(-1)

    except:
        importance_1.loc[idx] = 0

    count_df.loc[idx] = count
    count += 1
    print("")

importance_0['count'] = count_df
importance_1['count'] = count_df

val_acc = accuracy_score(valid_true_all, valid_pred_all)
val_f1 = f1_score(valid_true_all, valid_pred_all, average='macro')

test_acc = accuracy_score(test_true_all, test_pred_all)
test_f1 = f1_score(test_true_all, test_pred_all, average='macro')

print(f"{train_n} months")
print(f'Valid Acc : {val_acc*100:.2f}% Valid F1 : {val_f1*100:.2f}%')
print(f'Test Acc : {test_acc*100:.2f}% Test F1 : {test_f1*100:.2f}%')
print("")
print("Valid Confusion Matrix")
print(confusion_matrix(valid_true_all, valid_pred_all))
print("")
print("Test Confusion Matrix")
print(confusion_matrix(test_true_all, test_pred_all))
print("")

importance_0.to_csv(f"importance/importance_0.csv")
importance_1.to_csv(f"importance/importance_1.csv")
test_df.to_csv(f"importance/pred.csv")
# Out:
#   0%|          | 0/26 [00:00<?, ?it/s]
# 1/26 2021-01-04 training start
# [   5/1000] train_loss: 0.68986 train acc: 0.53 valid_loss: 0.70059 valid acc: 0.48
# [  10/1000] train_loss: 0.68810 train acc: 0.53 valid_loss: 0.70012 valid acc: 0.47
# [  15/1000] train_loss: 0.68279 train acc: 0.54 valid_loss: 0.71314 valid acc: 0.47
# [  20/1000] train_loss: 0.67494 train acc: 0.54 valid_loss: 0.71478 valid acc: 0.47
# [  25/1000] train_loss: 0.66803 train acc: 0.55 valid_loss: 0.70878 valid acc: 0.48
# [  30/1000] train_loss: 0.66130 train acc: 0.55 valid_loss: 0.70579 valid acc: 0.49
# [  35/1000] train_loss: 0.64810 train acc: 0.56 valid_loss: 0.70089 valid acc: 0.50
# [  40/1000] train_loss: 0.63300 train acc: 0.57 valid_loss: 0.69835 valid acc: 0.50
#
# 2/26 2021-01-18 training start
# [   5/1000] train_loss: 0.69031 train acc: 0.53 valid_loss: 0.69262 valid acc: 0.51
# [  10/1000] train_loss: 0.69032 train acc: 0.53 valid_loss: 0.70987 valid acc: 0.51
# [  15/1000] train_loss: 0.68864 train acc: 0.54 valid_loss: 0.70419 valid acc: 0.51
# [  20/1000] train_loss: 0.68593 train acc: 0.54 valid_loss: 0.69825 valid acc: 0.51
# [  25/1000] train_loss: 0.68419 train acc: 0.54 valid_loss: 0.69995 valid acc: 0.51
# [  30/1000] train_loss: 0.67954 train acc: 0.54 valid_loss: 0.69251 valid acc: 0.51
#
# 3/26 2021-02-01 training start
# [   5/1000] train_loss: 0.69038 train acc: 0.53 valid_loss: 0.69091 valid acc: 0.51
# [  10/1000] train_loss: 0.68816 train acc: 0.54 valid_loss: 0.70103 valid acc: 0.50
# [  15/1000] train_loss: 0.68711 train acc: 0.54 valid_loss: 0.69756 valid acc: 0.51
# [  20/1000] train_loss: 0.68317 train acc: 0.54 valid_loss: 0.70758 valid acc: 0.51
# [  25/1000] train_loss: 0.67765 train acc: 0.55 valid_loss: 0.70683 valid acc: 0.51
# [  30/1000] train_loss: 0.67111 train acc: 0.55 valid_loss: 0.71720 valid acc: 0.51
#
# 4/26 2021-02-15 training start
# [   5/1000] train_loss: 0.69062 train acc: 0.52 valid_loss: 0.70010 valid acc: 0.45
# [  10/1000] train_loss: 0.68806 train acc: 0.53 valid_loss: 0.70385 valid acc: 0.46
# [  15/1000] train_loss: 0.68677 train acc: 0.53 valid_loss: 0.70422 valid acc: 0.45
# [  20/1000] train_loss: 0.68274 train acc: 0.54 valid_loss: 0.69916 valid acc: 0.44
# [  25/1000] train_loss: 0.67767 train acc: 0.54 valid_loss: 0.72115 valid acc: 0.43
# [  30/1000] train_loss: 0.67046 train acc: 0.55 valid_loss: 0.72291 valid acc: 0.43
# [  35/1000] train_loss: 0.66160 train acc: 0.55 valid_loss: 0.72090 valid acc: 0.44
# [  40/1000] train_loss: 0.65352 train acc: 0.56 valid_loss: 0.75131 valid acc: 0.44
#
# 5/26 2021-03-01 training start
# [   5/1000] train_loss: 0.69062 train acc: 0.53 valid_loss: 0.69738 valid acc: 0.50
# [  10/1000] train_loss: 0.68949 train acc: 0.53 valid_loss: 0.69460 valid acc: 0.50
# [  15/1000] train_loss: 0.68943 train acc: 0.54 valid_loss: 0.69887 valid acc: 0.49
# [  20/1000] train_loss: 0.68816 train acc: 0.54 valid_loss: 0.69626 valid acc: 0.49
# [  25/1000] train_loss: 0.68622 train acc: 0.54 valid_loss: 0.70164 valid acc: 0.48
# [  30/1000] train_loss: 0.68169 train acc: 0.54 valid_loss: 0.71104 valid acc: 0.48
# [  35/1000] train_loss: 0.67163 train acc: 0.55 valid_loss: 0.70764 valid acc: 0.48
# [  40/1000] train_loss: 0.66281 train acc: 0.55 valid_loss: 0.74321 valid acc: 0.48
#
# 6/26 2021-03-15 training start
# [   5/1000] train_loss: 0.69087 train acc: 0.52 valid_loss: 0.69611 valid acc: 0.46
# [  10/1000] train_loss: 0.68808 train acc: 0.53 valid_loss: 0.70574 valid acc: 0.47
# [  15/1000] train_loss: 0.68740 train acc: 0.53 valid_loss: 0.69942 valid acc: 0.47
# [  20/1000] train_loss: 0.68191 train acc: 0.54 valid_loss: 0.70799 valid acc: 0.46
# [  25/1000] train_loss: 0.67791 train acc: 0.54 valid_loss: 0.70717 valid acc: 0.47
# [  30/1000] train_loss: 0.67259 train acc: 0.54 valid_loss: 0.71478 valid acc: 0.46
# [  35/1000] train_loss: 0.66452 train acc: 0.55 valid_loss: 0.76329 valid acc: 0.46
#
# 7/26 2021-03-29 training start
# [   5/1000] train_loss: 0.69180 train acc: 0.53 valid_loss: 0.70524 valid acc: 0.50
# [  10/1000] train_loss: 0.68836 train acc: 0.53 valid_loss: 0.69637 valid acc: 0.50
# [  15/1000] train_loss: 0.68677 train acc: 0.53 valid_loss: 0.69683 valid acc: 0.50
# [  20/1000] train_loss: 0.68321 train acc: 0.54 valid_loss: 0.71150 valid acc: 0.49
# [  25/1000] train_loss: 0.67416 train acc: 0.54 valid_loss: 0.71726 valid acc: 0.49
# [  30/1000] train_loss: 0.66858 train acc: 0.55 valid_loss: 0.71659 valid acc: 0.49
#
# 8/26 2021-04-12 training start
# [   5/1000] train_loss: 0.69166 train acc: 0.52 valid_loss: 0.69620 valid acc: 0.50
# [  10/1000] train_loss: 0.69119 train acc: 0.53 valid_loss: 0.69171 valid acc: 0.50
# [  15/1000] train_loss: 0.69060 train acc: 0.53 valid_loss: 0.70216 valid acc: 0.50
# [  20/1000] train_loss: 0.68750 train acc: 0.53 valid_loss: 0.70697 valid acc: 0.49
# [  25/1000] train_loss: 0.68286 train acc: 0.54 valid_loss: 0.69631 valid acc: 0.48
# [  30/1000] train_loss: 0.67424 train acc: 0.54 valid_loss: 0.72051 valid acc: 0.47
#
# 9/26 2021-04-26 training start
# [   5/1000] train_loss: 0.69173 train acc: 0.53 valid_loss: 0.69713 valid acc: 0.50
# [  10/1000] train_loss: 0.69123 train acc: 0.53 valid_loss: 0.68811 valid acc: 0.50
# [  15/1000] train_loss: 0.69053 train acc: 0.53 valid_loss: 0.69450 valid acc: 0.50
# [  20/1000] train_loss: 0.68695 train acc: 0.53 valid_loss: 0.69455 valid acc: 0.49
# [  25/1000] train_loss: 0.68055 train acc: 0.53 valid_loss: 0.70587 valid acc: 0.49
# [  30/1000] train_loss: 0.67020 train acc: 0.54 valid_loss: 0.67209 valid acc: 0.49
# [  35/1000] train_loss: 0.66334 train acc: 0.55 valid_loss: 0.72017 valid acc: 0.49
# [  40/1000] train_loss: 0.65790 train acc: 0.55 valid_loss: 0.72101 valid acc: 0.49
# [  45/1000] train_loss: 0.64220 train acc: 0.56 valid_loss: 0.78222 valid acc: 0.49
# [  50/1000] train_loss: 0.63334 train acc: 0.57 valid_loss: 0.75694 valid acc: 0.49
#
# 10/26 2021-05-10 training start
# [   5/1000] train_loss: 0.69227 train acc: 0.52 valid_loss: 0.68889 valid acc: 0.55
# [  10/1000] train_loss: 0.69097 train acc: 0.52 valid_loss: 0.69624 valid acc: 0.53
# [  15/1000] train_loss: 0.69043 train acc: 0.52 valid_loss: 0.68710 valid acc: 0.52
# [  20/1000] train_loss: 0.68775 train acc: 0.52 valid_loss: 0.68913 valid acc: 0.52
# [  25/1000] train_loss: 0.68218 train acc: 0.53 valid_loss: 0.69849 valid acc: 0.52
# [  30/1000] train_loss: 0.67868 train acc: 0.53 valid_loss: 0.69608 valid acc: 0.52
# [  35/1000] train_loss: 0.67205 train acc: 0.54 valid_loss: 0.72102 valid acc: 0.52
#
# 11/26 2021-05-24 training start
# [   5/1000] train_loss: 0.69092 train acc: 0.53 valid_loss: 0.69304 valid acc: 0.53
# [  10/1000] train_loss: 0.69144 train acc: 0.53 valid_loss: 0.68873 valid acc: 0.51
# [  15/1000] train_loss: 0.69148 train acc: 0.53 valid_loss: 0.69520 valid acc: 0.52
# [  20/1000] train_loss: 0.69167 train acc: 0.53 valid_loss: 0.69273 valid acc: 0.51
# [  25/1000] train_loss: 0.69074 train acc: 0.53 valid_loss: 0.69220 valid acc: 0.51
# [  30/1000] train_loss: 0.68944 train acc: 0.53 valid_loss: 0.70141 valid acc: 0.51
# [  35/1000] train_loss: 0.68708 train acc: 0.53 valid_loss: 0.68596 valid acc: 0.51
# [  40/1000] train_loss: 0.68060 train acc: 0.53 valid_loss: 0.70576 valid acc: 0.51
# [  45/1000] train_loss: 0.67831 train acc: 0.53 valid_loss: 0.69949 valid acc: 0.51
# [  50/1000] train_loss: 0.66638 train acc: 0.54 valid_loss: 0.69956 valid acc: 0.51
# [  55/1000] train_loss: 0.65679 train acc: 0.54 valid_loss: 0.75507 valid acc: 0.50
# [  60/1000] train_loss: 0.63928 train acc: 0.54 valid_loss: 0.74837 valid acc: 0.50
# [  65/1000] train_loss: 0.63316 train acc: 0.55 valid_loss: 0.70764 valid acc: 0.50
# [  70/1000] train_loss: 0.61968 train acc: 0.55 valid_loss: 0.74309 valid acc: 0.51
# [  75/1000] train_loss: 0.60761 train acc: 0.56 valid_loss: 0.73018 valid acc: 0.51
# [  80/1000] train_loss: 0.60170 train acc: 0.56 valid_loss: 0.76328 valid acc: 0.51
# [  85/1000] train_loss: 0.58931 train acc: 0.57 valid_loss: 0.71676 valid acc: 0.51
# [  90/1000] train_loss: 0.58429 train acc: 0.57 valid_loss: 0.72660 valid acc: 0.51
#
# 12/26 2021-06-07 training start
# [   5/1000] train_loss: 0.69281 train acc: 0.51 valid_loss: 0.69426 valid acc: 0.50
# [  10/1000] train_loss: 0.69079 train acc: 0.52 valid_loss: 0.69234 valid acc: 0.50
# [  15/1000] train_loss: 0.68819 train acc: 0.52 valid_loss: 0.69518 valid acc: 0.50
# [  20/1000] train_loss: 0.68497 train acc: 0.53 valid_loss: 0.69498 valid acc: 0.50
# [  25/1000] train_loss: 0.67992 train acc: 0.53 valid_loss: 0.69557 valid acc: 0.50
# [  30/1000] train_loss: 0.67070 train acc: 0.54 valid_loss: 0.68954 valid acc: 0.50
# [  35/1000] train_loss: 0.66521 train acc: 0.55 valid_loss: 0.69142 valid acc: 0.50
# [  40/1000] train_loss: 0.65822 train acc: 0.55 valid_loss: 0.68054 valid acc: 0.51
# [  45/1000] train_loss: 0.64585 train acc: 0.56 valid_loss: 0.69411 valid acc: 0.51
# [  50/1000] train_loss: 0.63582 train acc: 0.56 valid_loss: 0.70294 valid acc: 0.51
# [  55/1000] train_loss: 0.61909 train acc: 0.57 valid_loss: 0.68566 valid acc: 0.51
# [  60/1000] train_loss: 0.60051 train acc: 0.58 valid_loss: 0.71963 valid acc: 0.51
# [  65/1000] train_loss: 0.59013 train acc: 0.59 valid_loss: 0.67572 valid acc: 0.52
#
# 13/26 2021-06-21 training start
# [   5/1000] train_loss: 0.69115 train acc: 0.51 valid_loss: 0.69564 valid acc: 0.48
# [  10/1000] train_loss: 0.69099 train acc: 0.52 valid_loss: 0.69545 valid acc: 0.49
# [  15/1000] train_loss: 0.68965 train acc: 0.52 valid_loss: 0.69259 valid acc: 0.49
# [  20/1000] train_loss: 0.68818 train acc: 0.52 valid_loss: 0.69583 valid acc: 0.49
# [  25/1000] train_loss: 0.68378 train acc: 0.52 valid_loss: 0.69395 valid acc: 0.49
# [  30/1000] train_loss: 0.67167 train acc: 0.53 valid_loss: 0.68990 valid acc: 0.50
# [  35/1000] train_loss: 0.66345 train acc: 0.54 valid_loss: 0.69410 valid acc: 0.50
# [  40/1000] train_loss: 0.65090 train acc: 0.55 valid_loss: 0.69970 valid acc: 0.50
# [  45/1000] train_loss: 0.63465 train acc: 0.55 valid_loss: 0.69844 valid acc: 0.50
# [  50/1000] train_loss: 0.62147 train acc: 0.56 valid_loss: 0.71105 valid acc: 0.50
# [  55/1000] train_loss: 0.60441 train acc: 0.57 valid_loss: 0.71762 valid acc: 0.50
#
# 14/26 2021-07-05 training start
# [   5/1000] train_loss: 0.69228 train acc: 0.51 valid_loss: 0.69553 valid acc: 0.49
# [  10/1000] train_loss: 0.69055 train acc: 0.52 valid_loss: 0.69516 valid acc: 0.48
# [  15/1000] train_loss: 0.68954 train acc: 0.52 valid_loss: 0.69233 valid acc: 0.49
# [  20/1000] train_loss: 0.68792 train acc: 0.52 valid_loss: 0.69789 valid acc: 0.49
# [  25/1000] train_loss: 0.68535 train acc: 0.52 valid_loss: 0.69205 valid acc: 0.48
# [  30/1000] train_loss: 0.67960 train acc: 0.53 valid_loss: 0.69005 valid acc: 0.49
# [  35/1000] train_loss: 0.66780 train acc: 0.53 valid_loss: 0.68340 valid acc: 0.50
# [  40/1000] train_loss: 0.65700 train acc: 0.54 valid_loss: 0.69529 valid acc: 0.51
# [  45/1000] train_loss: 0.65193 train acc: 0.55 valid_loss: 0.69899 valid acc: 0.51
# [  50/1000] train_loss: 0.63823 train acc: 0.56 valid_loss: 0.70504 valid acc: 0.51
#
# 15/26 2021-07-19 training start
# [   5/1000] train_loss: 0.69231 train acc: 0.52 valid_loss: 0.69270 valid acc: 0.50
# [  10/1000] train_loss: 0.69077 train acc: 0.52 valid_loss: 0.69599 valid acc: 0.49
# [  15/1000] train_loss: 0.68993 train acc: 0.53 valid_loss: 0.69408 valid acc: 0.49
# [  20/1000] train_loss: 0.68839 train acc: 0.53 valid_loss: 0.69083 valid acc: 0.49
# [  25/1000] train_loss: 0.68051 train acc: 0.53 valid_loss: 0.69129 valid acc: 0.49
# [  30/1000] train_loss: 0.67279 train acc: 0.54 valid_loss: 0.68141 valid acc: 0.50
# [  35/1000] train_loss: 0.66151 train acc: 0.54 valid_loss: 0.68257 valid acc: 0.50
# [  40/1000] train_loss: 0.65244 train acc: 0.55 valid_loss: 0.68348 valid acc: 0.50
# [  45/1000] train_loss: 0.63959 train acc: 0.56 valid_loss: 0.70867 valid acc: 0.51
# [  50/1000] train_loss: 0.63275 train acc: 0.57 valid_loss: 0.68622 valid acc: 0.51
# [  55/1000] train_loss: 0.61230 train acc: 0.57 valid_loss: 0.70849 valid acc: 0.51
# [  60/1000] train_loss: 0.60412 train acc: 0.58 valid_loss: 0.72240 valid acc: 0.52
#
# 16/26 2021-08-02 training start
# [   5/1000] train_loss: 0.69253 train acc: 0.52 valid_loss: 0.69621 valid acc: 0.49
# [  10/1000] train_loss: 0.69179 train acc: 0.53 valid_loss: 0.69582 valid acc: 0.48
# [  15/1000] train_loss: 0.69066 train acc: 0.53 valid_loss: 0.69652 valid acc: 0.48
# [  20/1000] train_loss: 0.68922 train acc: 0.53 valid_loss: 0.69697 valid acc: 0.48
# [  25/1000] train_loss: 0.68351 train acc: 0.53 valid_loss: 0.68972 valid acc: 0.49
# [  30/1000] train_loss: 0.67914 train acc: 0.54 valid_loss: 0.70102 valid acc: 0.49
# [  35/1000] train_loss: 0.66834 train acc: 0.54 valid_loss: 0.71833 valid acc: 0.49
# [  40/1000] train_loss: 0.65736 train acc: 0.55 valid_loss: 0.74642 valid acc: 0.49
# [  45/1000] train_loss: 0.65299 train acc: 0.56 valid_loss: 0.72003 valid acc: 0.49
#
# 17/26 2021-08-16 training start
# [   5/1000] train_loss: 0.69224 train acc: 0.52 valid_loss: 0.69481 valid acc: 0.49
# [  10/1000] train_loss: 0.69203 train acc: 0.53 valid_loss: 0.69315 valid acc: 0.49
# [  15/1000] train_loss: 0.68885 train acc: 0.53 valid_loss: 0.69574 valid acc: 0.49
# [  20/1000] train_loss: 0.68322 train acc: 0.53 valid_loss: 0.69495 valid acc: 0.50
# [  25/1000] train_loss: 0.67383 train acc: 0.54 valid_loss: 0.68889 valid acc: 0.50
# [  30/1000] train_loss: 0.66198 train acc: 0.55 valid_loss: 0.68079 valid acc: 0.51
# [  35/1000] train_loss: 0.64988 train acc: 0.56 valid_loss: 0.66807 valid acc: 0.52
# [  40/1000] train_loss: 0.63461 train acc: 0.56 valid_loss: 0.67974 valid acc: 0.53
# [  45/1000] train_loss: 0.62631 train acc: 0.57 valid_loss: 0.68771 valid acc: 0.53
# [  50/1000] train_loss: 0.61517 train acc: 0.58 valid_loss: 0.70196 valid acc: 0.53
# [  55/1000] train_loss: 0.60070 train acc: 0.59 valid_loss: 0.68602 valid acc: 0.53
#
# 18/26 2021-08-30 training start
# [   5/1000] train_loss: 0.69139 train acc: 0.52 valid_loss: 0.69205 valid acc: 0.52
# [  10/1000] train_loss: 0.68845 train acc: 0.52 valid_loss: 0.69061 valid acc: 0.51
# [  15/1000] train_loss: 0.68546 train acc: 0.53 valid_loss: 0.68631 valid acc: 0.51
# [  20/1000] train_loss: 0.67644 train acc: 0.53 valid_loss: 0.68984 valid acc: 0.50
# [  25/1000] train_loss: 0.66238 train acc: 0.54 valid_loss: 0.68442 valid acc: 0.50
# [  30/1000] train_loss: 0.65474 train acc: 0.55 valid_loss: 0.69411 valid acc: 0.50
# [  35/1000] train_loss: 0.64067 train acc: 0.56 valid_loss: 0.69098 valid acc: 0.50
# [  40/1000] train_loss: 0.62225 train acc: 0.57 valid_loss: 0.70231 valid acc: 0.50
#
# 19/26 2021-09-13 training start
# [   5/1000] train_loss: 0.69211 train acc: 0.52 valid_loss: 0.69737 valid acc: 0.49
# [  10/1000] train_loss: 0.69135 train acc: 0.52 valid_loss: 0.69911 valid acc: 0.50
# [  15/1000] train_loss: 0.68981 train acc: 0.52 valid_loss: 0.69532 valid acc: 0.50
# [  20/1000] train_loss: 0.68977 train acc: 0.52 valid_loss: 0.68723 valid acc: 0.50
# [  25/1000] train_loss: 0.68541 train acc: 0.53 valid_loss: 0.70600 valid acc: 0.49
# [  30/1000] train_loss: 0.67846 train acc: 0.53 valid_loss: 0.69419 valid acc: 0.48
# [  35/1000] train_loss: 0.67322 train acc: 0.54 valid_loss: 0.73481 valid acc: 0.48
# [  40/1000] train_loss: 0.66093 train acc: 0.54 valid_loss: 0.71055 valid acc: 0.48
#
# 20/26 2021-09-27 training start
# [   5/1000] train_loss: 0.69153 train acc: 0.53 valid_loss: 0.69517 valid acc: 0.50
# [  10/1000] train_loss: 0.69125 train acc: 0.53 valid_loss: 0.69789 valid acc: 0.50
# [  15/1000] train_loss: 0.68927 train acc: 0.53 valid_loss: 0.69593 valid acc: 0.49
# [  20/1000] train_loss: 0.68096 train acc: 0.54 valid_loss: 0.70753 valid acc: 0.49
# [  25/1000] train_loss: 0.66740 train acc: 0.55 valid_loss: 0.70321 valid acc: 0.49
# [  30/1000] train_loss: 0.65420 train acc: 0.56 valid_loss: 0.71208 valid acc: 0.49
# [  35/1000] train_loss: 0.63330 train acc: 0.56 valid_loss: 0.74034 valid acc: 0.49
#
# 21/26 2021-10-11 training start
# [   5/1000] train_loss: 0.69325 train acc: 0.51 valid_loss: 0.69902 valid acc: 0.52
# [  10/1000] train_loss: 0.69127 train acc: 0.52 valid_loss: 0.69927 valid acc: 0.51
# [  15/1000] train_loss: 0.68780 train acc: 0.52 valid_loss: 0.70368 valid acc: 0.51
# [  20/1000] train_loss: 0.68452 train acc: 0.53 valid_loss: 0.69957 valid acc: 0.50
# [  25/1000] train_loss: 0.67363 train acc: 0.54 valid_loss: 0.66875 valid acc: 0.49
# [  30/1000] train_loss: 0.66776 train acc: 0.54 valid_loss: 0.75559 valid acc: 0.49
#
# 22/26 2021-10-25 training start
# [   5/1000] train_loss: 0.69232 train acc: 0.51 valid_loss: 0.69562 valid acc: 0.49
# [  10/1000] train_loss: 0.69085 train acc: 0.52 valid_loss: 0.67817 valid acc: 0.50
# [  15/1000] train_loss: 0.68911 train acc: 0.52 valid_loss: 0.68914 valid acc: 0.50
# [  20/1000] train_loss: 0.68073 train acc: 0.53 valid_loss: 0.68918 valid acc: 0.50
# [  25/1000] train_loss: 0.66917 train acc: 0.54 valid_loss: 0.73087 valid acc: 0.50
# [  30/1000] train_loss: 0.65410 train acc: 0.55 valid_loss: 0.62322 valid acc: 0.51
# [  35/1000] train_loss: 0.63646 train acc: 0.56 valid_loss: 0.73808 valid acc: 0.51
# [  40/1000] train_loss: 0.61497 train acc: 0.57 valid_loss: 0.68063 valid acc: 0.52
# [  45/1000] train_loss: 0.60698 train acc: 0.58 valid_loss: 0.68190 valid acc: 0.52
# [  50/1000] train_loss: 0.58392 train acc: 0.59 valid_loss: 0.64099 valid acc: 0.52
# [  55/1000] train_loss: 0.57841 train acc: 0.59 valid_loss: 0.68303 valid acc: 0.52
# [  60/1000] train_loss: 0.57584 train acc: 0.60 valid_loss: 0.93820 valid acc: 0.52
#
# 23/26 2021-11-08 training start
# [   5/1000] train_loss: 0.69261 train acc: 0.52 valid_loss: 0.69661 valid acc: 0.50
# [  10/1000] train_loss: 0.69131 train acc: 0.52 valid_loss: 0.69394 valid acc: 0.50
# [  15/1000] train_loss: 0.68877 train acc: 0.53 valid_loss: 0.69071 valid acc: 0.49
# [  20/1000] train_loss: 0.68278 train acc: 0.53 valid_loss: 0.70507 valid acc: 0.49
# [  25/1000] train_loss: 0.66813 train acc: 0.54 valid_loss: 0.70626 valid acc: 0.49
# [  30/1000] train_loss: 0.66484 train acc: 0.55 valid_loss: 0.68331 valid acc: 0.49
# [  35/1000] train_loss: 0.64980 train acc: 0.56 valid_loss: 0.73086 valid acc: 0.49
# [  40/1000] train_loss: 0.63486 train acc: 0.57 valid_loss: 0.73913 valid acc: 0.49
# [  45/1000] train_loss: 0.61116 train acc: 0.57 valid_loss: 0.74087 valid acc: 0.48
# [  50/1000] train_loss: 0.60204 train acc: 0.58 valid_loss: 0.75231 valid acc: 0.48
#
# 24/26 2021-11-22 training start
# [   5/1000] train_loss: 0.69242 train acc: 0.52 valid_loss: 0.69553 valid acc: 0.51
# [  10/1000] train_loss: 0.69163 train acc: 0.52 valid_loss: 0.69156 valid acc: 0.50
# [  15/1000] train_loss: 0.68904 train acc: 0.52 valid_loss: 0.69314 valid acc: 0.50
# [  20/1000] train_loss: 0.68482 train acc: 0.53 valid_loss: 0.69070 valid acc: 0.50
# [  25/1000] train_loss: 0.67808 train acc: 0.53 valid_loss: 0.69447 valid acc: 0.50
# [  30/1000] train_loss: 0.66317 train acc: 0.54 valid_loss: 0.69735 valid acc: 0.50
# [  35/1000] train_loss: 0.64523 train acc: 0.55 valid_loss: 0.68779 valid acc: 0.50
# [  40/1000] train_loss: 0.63686 train acc: 0.56 valid_loss: 0.71251 valid acc: 0.49
#
# 25/26 2021-12-06 training start
# [   5/1000] train_loss: 0.69198 train acc: 0.51 valid_loss: 0.69300 valid acc: 0.49
# [  10/1000] train_loss: 0.69281 train acc: 0.52 valid_loss: 0.69158 valid acc: 0.50
# [  15/1000] train_loss: 0.69075 train acc: 0.52 valid_loss: 0.70023 valid acc: 0.50
# [  20/1000] train_loss: 0.68880 train acc: 0.52 valid_loss: 0.68837 valid acc: 0.50
# [  25/1000] train_loss: 0.68473 train acc: 0.52 valid_loss: 0.69488 valid acc: 0.50
# [  30/1000] train_loss: 0.67706 train acc: 0.53 valid_loss: 0.71252 valid acc: 0.50
#
# 26/26 2021-12-20 training start
# [   5/1000] train_loss: 0.69267 train acc: 0.51 valid_loss: 0.69449 valid acc: 0.50
# [  10/1000] train_loss: 0.69207 train acc: 0.51 valid_loss: 0.69305 valid acc: 0.49
# [  15/1000] train_loss: 0.68834 train acc: 0.52 valid_loss: 0.68595 valid acc: 0.50
# [  20/1000] train_loss: 0.68366 train acc: 0.52 valid_loss: 0.68620 valid acc: 0.51
# [  25/1000] train_loss: 0.67998 train acc: 0.53 valid_loss: 0.68180 valid acc: 0.51
# [  30/1000] train_loss: 0.66830 train acc: 0.54 valid_loss: 0.69989 valid acc: 0.51
# [  35/1000] train_loss: 0.65220 train acc: 0.54 valid_loss: 0.68042 valid acc: 0.52
# [  40/1000] train_loss: 0.65013 train acc: 0.55 valid_loss: 0.69564 valid acc: 0.52
# [  45/1000] train_loss: 0.63333 train acc: 0.56 valid_loss: 0.70671 valid acc: 0.52
# [  50/1000] train_loss: 0.62131 train acc: 0.57 valid_loss: 0.69466 valid acc: 0.52
# [  55/1000] train_loss: 0.61485 train acc: 0.57 valid_loss: 0.67540 valid acc: 0.53
# [  60/1000] train_loss: 0.61440 train acc: 0.58 valid_loss: 0.68130 valid acc: 0.53
# [  65/1000] train_loss: 0.60169 train acc: 0.58 valid_loss: 0.69703 valid acc: 0.53
# [  70/1000] train_loss: 0.59087 train acc: 0.59 valid_loss: 0.71930 valid acc: 0.53
#
# 18 months
# Valid Acc : 51.95% Valid F1 : 48.89%
# Test Acc : 50.33% Test F1 : 47.30%
#
# Valid Confusion Matrix
# [[1314  476]
#  [1177  473]]
#
# Test Confusion Matrix
# [[1281  502]
#  [1210  454]]
#
# Wall time: 5min 9s

# %%
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

from time import time
from pathlib import Path
import sys, os
from tqdm.auto import tqdm

import datetime
import numpy as np
import pandas as pd
import random

from sklearn.preprocessing import MinMaxScaler, RobustScaler, StandardScaler
from scipy.stats import spearmanr
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import SMOTE, RandomOverSampler

import torch
from torch.utils.data import TensorDataset, DataLoader

from pytorch_grad_cam import GradCAM, ScoreCAM, GradCAMPlusPlus, AblationCAM, XGradCAM, EigenCAM
from pytorch_grad_cam.utils.image import show_cam_on_image
from pytorch_grad_cam.utils.model_targets import ClassifierOutputTarget

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, f1_score
from sklearn.model_selection import train_test_split

np.set_printoptions(precision=3, suppress=True)

# pakage for study
from utils import *

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

torch.manual_seed(777)

print(device)
# Out:
# cuda

# %%
data_raw = pd.read_csv("data/2.kospi200futures_clustered.csv")
data_raw.date = pd.to_datetime(data_raw.date, format='%Y%m%d')
data_raw = data_raw.set_index(['date','time'])

drop_cols = ["1_updown", "5_updown", "21_updown", "close"]
target = "1_updown"

data = data_raw.dropna()

date_list = list(data.index.get_level_values("date").unique())

# %%
test_num = 26*5

date = datetime.datetime.strptime("2021-12-20", "%Y-%m-%d")
test_start_dates = [date]

for n in range(1,test_num):
    date = date - datetime.timedelta(days=14)
    test_start_dates.append(date)
    
test_start_dates = test_start_dates[::-1]

# %%
random.seed(907)

valid_size = 14
test_size = 14
    
batch_size = 64
n_epochs = 1000
T_max = n_epochs / 100

start_lr = 0.001
min_lr = 0.00001

# early stopping patience;
# how long to wait since the last time the validation loss improved
patience = 20
view_time = 4

feature_list = [x.split('_')[-1] for x in data.columns[:16]]
columns_list = data.drop(drop_cols, axis=1).columns
num_list = [x.split('_')[0] for x in columns_list[::16]]

# train months
train_n = 18
train_size = 30 * train_n

# %%
# %%time

test_df = pd.DataFrame()
importance_0 = pd.DataFrame(columns=columns_list)
importance_1 = pd.DataFrame(columns=columns_list)
count_df = pd.DataFrame(columns=['count'])

valid_true_all = []
valid_pred_all = []
test_true_all = []
test_pred_all = []

count = 1
total_count = 26
for test_start in tqdm(test_start_dates[-total_count:]):
    
    print(f"{count}/{total_count} {test_start.strftime('%Y-%m-%d')} training start")
    
    train_data, valid_data, test_data = make_rolling(data, test_start, test_size, valid_size=valid_size, train_size=train_size)

    # Generate dataset
    train_X = train_data.drop(drop_cols, axis=1)
    train_y = train_data[target]

    valid_X = valid_data.drop(drop_cols, axis=1)
    valid_y = valid_data[target]

    test_X = test_data.drop(drop_cols,axis=1)
    test_y = test_data[target]

    test_indexs = test_data.index

    # Scaler
    scaler = RobustScaler()
    scaler.fit(train_X)

    train_X = scaler.transform(train_X)
    valid_X = scaler.transform(valid_X)
    test_X = scaler.transform(test_X)

    # SMOTE over sample for validation dataset
    smote = SMOTE(random_state=0, )
    randomoversampling = RandomOverSampler(random_state=0)
    try:
        valid_X_SMOTE, valid_y_SMOTE = smote.fit_resample(valid_X, valid_y)
    except:
        valid_X_SMOTE, valid_y_SMOTE = randomoversampling.fit_resample(valid_X, valid_y)

    # Reshape
    train_X = train_X.reshape(-1, 1, 16, 16)
    valid_X_SMOTE = valid_X_SMOTE.reshape(-1, 1, 16, 16)
    test_X = test_X.reshape(-1, 1, 16, 16)

    # convert to tensor
    train_X_tensor = torch.FloatTensor(train_X).to(device)
    train_y_tensor = torch.LongTensor(train_y.values).to(device)

    valid_X_tensor = torch.FloatTensor(valid_X_SMOTE).to(device)
    valid_y_tensor = torch.LongTensor(valid_y_SMOTE.values).to(device)

    test_X_tensor = torch.FloatTensor(test_X).to(device)
    test_y_tensor = torch.LongTensor(test_y.values).to(device)

    model = CNN(output_size=2).to(device)
    model.apply(weight_init_uniform)

    # loss & optimizer setting
    criterion = torch.nn.CrossEntropyLoss().to(device)

    optimizer = torch.optim.Adam(model.parameters(), lr=start_lr)
    scheduler = get_scheduler(optimizer, T_max, min_lr)

    # make dataset and dataloader
    train_dataset = TensorDataset(train_X_tensor, train_y_tensor)
    valid_dataset = TensorDataset(valid_X_tensor, valid_y_tensor)

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=True)

    model, train_loss, valid_loss = train_model(model, train_loader, valid_loader, optimizer, criterion, patience, n_epochs, view_time=view_time)

    # predict
    model = model.cpu()

    # set datasets
    train_X_tensor = train_X_tensor.to("cpu")
    train_y_tensor = train_y_tensor.to("cpu")

    valid_X = valid_X.reshape(-1, 1, 16, 16)
    valid_X_tensor = torch.FloatTensor(valid_X)
    valid_y_tensor = torch.LongTensor(valid_y.values)

    test_X_tensor = test_X_tensor.to("cpu")
    test_y_tensor = test_y_tensor.to("cpu")

    # predict
    train_y_pred = model(train_X_tensor).argmax(axis=1).tolist()
    valid_y_pred = model(valid_X_tensor).argmax(axis=1).tolist()
    test_y_pred = model(test_X_tensor).argmax(axis=1).tolist()

    valid_true_all += valid_y.to_list()
    valid_pred_all += valid_y_pred
    test_true_all += test_y.to_list()
    test_pred_all += test_y_pred

    test_df_temp = test_y.to_frame()
    test_df_temp['pred'] = test_y_pred
    test_df_temp['count'] = count

    test_df = pd.concat([test_df, test_df_temp])

    # average of correct answers

    target_layers = model.cnn_layer
    cam = GradCAM(model=model, target_layers=target_layers)

    correct_idx = [i for i, x in enumerate(np.array(valid_y) == np.array(valid_y_pred)) if x]
    np.random.seed(907)

    answer_0 = []
    answer_1 = []

    for num in correct_idx:
        answer = int(valid_y[num])
        X = torch.FloatTensor(valid_X[num])
        label = int(valid_y_pred[num])

        if answer == 0:
            # You can also pass aug_smooth=True and eigen_smooth=True, to apply smoothing.
            grayscale_cam = cam(input_tensor=X.unsqueeze(0), targets=[ClassifierOutputTarget(0)])
            # In this example grayscale_cam has only one image in the batch:
            grayscale_cam = grayscale_cam[0, :]

            answer_0.append(grayscale_cam)

        else:
            # You can also pass aug_smooth=True and eigen_smooth=True, to apply smoothing.
            grayscale_cam = cam(input_tensor=X.unsqueeze(0), targets=[ClassifierOutputTarget(1)])
            # In this example grayscale_cam has only one image in the batch:
            grayscale_cam = grayscale_cam[0, :]

            answer_1.append(grayscale_cam)

    idx = test_start.strftime('%Y-%m-%d')

    try:
        importance_0.loc[idx] = np.mean(answer_0, axis=0).reshape(-1)

    except:
        importance_0.loc[idx] = 0

    try:
        importance_1.loc[idx] = np.mean(answer_1, axis=0).reshape(-1)

    except:
        importance_1.loc[idx] = 0

    count_df.loc[idx] = count
    count += 1
    print("")

importance_0['count'] = count_df
importance_1['count'] = count_df

val_acc = accuracy_score(valid_true_all, valid_pred_all)
val_f1 = f1_score(valid_true_all, valid_pred_all, average='macro')

test_acc = accuracy_score(test_true_all, test_pred_all)
test_f1 = f1_score(test_true_all, test_pred_all, average='macro')

print(f"{train_n} months")
print(f'Valid Acc : {val_acc*100:.2f}% Valid F1 : {val_f1*100:.2f}%')
print(f'Test Acc : {test_acc*100:.2f}% Test F1 : {test_f1*100:.2f}%')
print("")
print("Valid Confusion Matrix")
print(confusion_matrix(valid_true_all, valid_pred_all))
print("")
print("Test Confusion Matrix")
print(confusion_matrix(test_true_all, test_pred_all))
print("")

importance_0.to_csv(f"importance/importance_0.csv")
importance_1.to_csv(f"importance/importance_1.csv")
test_df.to_csv(f"importance/pred.csv")
# Out:
#   0%|          | 0/26 [00:00<?, ?it/s]
# 1/26 2021-01-04 training start
# [   5/1000] train_loss: 0.68977 train acc: 0.53 valid_loss: 0.69877 valid acc: 0.49
# [  10/1000] train_loss: 0.68813 train acc: 0.53 valid_loss: 0.70170 valid acc: 0.47
# [  15/1000] train_loss: 0.68303 train acc: 0.54 valid_loss: 0.71570 valid acc: 0.47
# [  20/1000] train_loss: 0.67648 train acc: 0.54 valid_loss: 0.70641 valid acc: 0.47
# [  25/1000] train_loss: 0.67023 train acc: 0.55 valid_loss: 0.70069 valid acc: 0.48
# [  30/1000] train_loss: 0.66621 train acc: 0.55 valid_loss: 0.69253 valid acc: 0.50
# [  35/1000] train_loss: 0.65403 train acc: 0.56 valid_loss: 0.70272 valid acc: 0.50
# [  40/1000] train_loss: 0.64378 train acc: 0.57 valid_loss: 0.69225 valid acc: 0.50
# [  45/1000] train_loss: 0.62458 train acc: 0.57 valid_loss: 0.69876 valid acc: 0.51
#
# 2/26 2021-01-18 training start
# [   5/1000] train_loss: 0.69045 train acc: 0.53 valid_loss: 0.68873 valid acc: 0.51
# [  10/1000] train_loss: 0.68832 train acc: 0.54 valid_loss: 0.69639 valid acc: 0.51
# [  15/1000] train_loss: 0.68655 train acc: 0.54 valid_loss: 0.70202 valid acc: 0.51
# [  20/1000] train_loss: 0.68455 train acc: 0.54 valid_loss: 0.69389 valid acc: 0.50
# [  25/1000] train_loss: 0.67365 train acc: 0.55 valid_loss: 0.74356 valid acc: 0.50
# [  30/1000] train_loss: 0.66728 train acc: 0.56 valid_loss: 0.72688 valid acc: 0.50
# [  35/1000] train_loss: 0.64933 train acc: 0.56 valid_loss: 0.72810 valid acc: 0.50
# [  40/1000] train_loss: 0.64282 train acc: 0.57 valid_loss: 0.74290 valid acc: 0.50
#
# 3/26 2021-02-01 training start
# [   5/1000] train_loss: 0.69000 train acc: 0.53 valid_loss: 0.69772 valid acc: 0.49
# [  10/1000] train_loss: 0.68902 train acc: 0.54 valid_loss: 0.69355 valid acc: 0.50
# [  15/1000] train_loss: 0.68700 train acc: 0.54 valid_loss: 0.69283 valid acc: 0.50
# [  20/1000] train_loss: 0.68064 train acc: 0.54 valid_loss: 0.69809 valid acc: 0.50
# [  25/1000] train_loss: 0.67209 train acc: 0.55 valid_loss: 0.69571 valid acc: 0.50
# [  30/1000] train_loss: 0.66265 train acc: 0.55 valid_loss: 0.71856 valid acc: 0.50
# [  35/1000] train_loss: 0.65510 train acc: 0.56 valid_loss: 0.73071 valid acc: 0.50
# [  40/1000] train_loss: 0.64558 train acc: 0.57 valid_loss: 0.72786 valid acc: 0.50
#
# 4/26 2021-02-15 training start
# [   5/1000] train_loss: 0.69038 train acc: 0.52 valid_loss: 0.69622 valid acc: 0.50
# [  10/1000] train_loss: 0.68928 train acc: 0.53 valid_loss: 0.69763 valid acc: 0.49
# [  15/1000] train_loss: 0.68806 train acc: 0.53 valid_loss: 0.70075 valid acc: 0.48
# [  20/1000] train_loss: 0.68678 train acc: 0.54 valid_loss: 0.69544 valid acc: 0.48
# [  25/1000] train_loss: 0.68377 train acc: 0.54 valid_loss: 0.69852 valid acc: 0.47
# [  30/1000] train_loss: 0.68112 train acc: 0.54 valid_loss: 0.70845 valid acc: 0.47
# [  35/1000] train_loss: 0.67700 train acc: 0.54 valid_loss: 0.71327 valid acc: 0.46
#
# 5/26 2021-03-01 training start
# [   5/1000] train_loss: 0.69087 train acc: 0.53 valid_loss: 0.69437 valid acc: 0.50
# [  10/1000] train_loss: 0.68975 train acc: 0.53 valid_loss: 0.70379 valid acc: 0.50
# [  15/1000] train_loss: 0.68676 train acc: 0.53 valid_loss: 0.69816 valid acc: 0.50
# [  20/1000] train_loss: 0.68631 train acc: 0.54 valid_loss: 0.70057 valid acc: 0.50
# [  25/1000] train_loss: 0.68272 train acc: 0.54 valid_loss: 0.70599 valid acc: 0.49
# [  30/1000] train_loss: 0.67947 train acc: 0.54 valid_loss: 0.70989 valid acc: 0.48
#
# 6/26 2021-03-15 training start
# [   5/1000] train_loss: 0.69041 train acc: 0.53 valid_loss: 0.69659 valid acc: 0.50
# [  10/1000] train_loss: 0.68979 train acc: 0.53 valid_loss: 0.69953 valid acc: 0.50
# [  15/1000] train_loss: 0.68904 train acc: 0.53 valid_loss: 0.70358 valid acc: 0.49
# [  20/1000] train_loss: 0.68639 train acc: 0.54 valid_loss: 0.70054 valid acc: 0.48
# [  25/1000] train_loss: 0.68089 train acc: 0.54 valid_loss: 0.70887 valid acc: 0.48
# [  30/1000] train_loss: 0.67305 train acc: 0.54 valid_loss: 0.71188 valid acc: 0.48
#
# 7/26 2021-03-29 training start
# [   5/1000] train_loss: 0.69169 train acc: 0.53 valid_loss: 0.70035 valid acc: 0.49
# [  10/1000] train_loss: 0.69013 train acc: 0.53 valid_loss: 0.70154 valid acc: 0.49
# [  15/1000] train_loss: 0.68785 train acc: 0.53 valid_loss: 0.69736 valid acc: 0.49
# [  20/1000] train_loss: 0.68144 train acc: 0.54 valid_loss: 0.69240 valid acc: 0.49
# [  25/1000] train_loss: 0.67430 train acc: 0.54 valid_loss: 0.69713 valid acc: 0.49
# [  30/1000] train_loss: 0.66523 train acc: 0.55 valid_loss: 0.72425 valid acc: 0.49
# [  35/1000] train_loss: 0.65711 train acc: 0.56 valid_loss: 0.71036 valid acc: 0.49
# [  40/1000] train_loss: 0.63764 train acc: 0.56 valid_loss: 0.76273 valid acc: 0.49
#
# 8/26 2021-04-12 training start
# [   5/1000] train_loss: 0.69067 train acc: 0.53 valid_loss: 0.70134 valid acc: 0.50
# [  10/1000] train_loss: 0.68788 train acc: 0.53 valid_loss: 0.69085 valid acc: 0.50
# [  15/1000] train_loss: 0.68048 train acc: 0.54 valid_loss: 0.68949 valid acc: 0.50
# [  20/1000] train_loss: 0.66456 train acc: 0.55 valid_loss: 0.72092 valid acc: 0.50
# [  25/1000] train_loss: 0.65195 train acc: 0.56 valid_loss: 0.72645 valid acc: 0.49
# [  30/1000] train_loss: 0.63426 train acc: 0.57 valid_loss: 0.74291 valid acc: 0.49
# [  35/1000] train_loss: 0.60774 train acc: 0.58 valid_loss: 0.75625 valid acc: 0.49
#
# 9/26 2021-04-26 training start
# [   5/1000] train_loss: 0.69101 train acc: 0.52 valid_loss: 0.69309 valid acc: 0.50
# [  10/1000] train_loss: 0.68955 train acc: 0.52 valid_loss: 0.69415 valid acc: 0.50
# [  15/1000] train_loss: 0.68640 train acc: 0.53 valid_loss: 0.69210 valid acc: 0.50
# [  20/1000] train_loss: 0.68155 train acc: 0.53 valid_loss: 0.70118 valid acc: 0.50
# [  25/1000] train_loss: 0.67360 train acc: 0.54 valid_loss: 0.70622 valid acc: 0.50
# [  30/1000] train_loss: 0.67097 train acc: 0.55 valid_loss: 0.69308 valid acc: 0.50
# [  35/1000] train_loss: 0.65706 train acc: 0.56 valid_loss: 0.69389 valid acc: 0.50
# [  40/1000] train_loss: 0.64534 train acc: 0.56 valid_loss: 0.68902 valid acc: 0.50
# [  45/1000] train_loss: 0.63546 train acc: 0.57 valid_loss: 0.70543 valid acc: 0.50
#
# 10/26 2021-05-10 training start
# [   5/1000] train_loss: 0.69207 train acc: 0.52 valid_loss: 0.69038 valid acc: 0.50
# [  10/1000] train_loss: 0.69100 train acc: 0.53 valid_loss: 0.69065 valid acc: 0.50
# [  15/1000] train_loss: 0.68950 train acc: 0.53 valid_loss: 0.68933 valid acc: 0.51
# [  20/1000] train_loss: 0.68294 train acc: 0.53 valid_loss: 0.69238 valid acc: 0.52
# [  25/1000] train_loss: 0.67361 train acc: 0.54 valid_loss: 0.68654 valid acc: 0.52
# [  30/1000] train_loss: 0.65961 train acc: 0.55 valid_loss: 0.67628 valid acc: 0.53
# [  35/1000] train_loss: 0.64720 train acc: 0.56 valid_loss: 0.70562 valid acc: 0.53
# [  40/1000] train_loss: 0.63462 train acc: 0.56 valid_loss: 0.71349 valid acc: 0.53
# [  45/1000] train_loss: 0.61338 train acc: 0.57 valid_loss: 0.70298 valid acc: 0.53
# [  50/1000] train_loss: 0.59419 train acc: 0.58 valid_loss: 0.70190 valid acc: 0.53
# [  55/1000] train_loss: 0.58002 train acc: 0.59 valid_loss: 0.69857 valid acc: 0.53
# [  60/1000] train_loss: 0.55781 train acc: 0.60 valid_loss: 0.68977 valid acc: 0.53
# [  65/1000] train_loss: 0.55900 train acc: 0.61 valid_loss: 0.72751 valid acc: 0.53
# [  70/1000] train_loss: 0.54955 train acc: 0.62 valid_loss: 0.68210 valid acc: 0.53
# [  75/1000] train_loss: 0.53019 train acc: 0.62 valid_loss: 0.74212 valid acc: 0.53
#
# 11/26 2021-05-24 training start
# [   5/1000] train_loss: 0.69092 train acc: 0.52 valid_loss: 0.69377 valid acc: 0.49
# [  10/1000] train_loss: 0.68867 train acc: 0.52 valid_loss: 0.68815 valid acc: 0.50
# [  15/1000] train_loss: 0.68376 train acc: 0.53 valid_loss: 0.70616 valid acc: 0.50
# [  20/1000] train_loss: 0.67706 train acc: 0.54 valid_loss: 0.69773 valid acc: 0.50
# [  25/1000] train_loss: 0.66759 train acc: 0.54 valid_loss: 0.70065 valid acc: 0.50
# [  30/1000] train_loss: 0.65208 train acc: 0.55 valid_loss: 0.67292 valid acc: 0.51
# [  35/1000] train_loss: 0.63628 train acc: 0.56 valid_loss: 0.72613 valid acc: 0.52
# [  40/1000] train_loss: 0.62168 train acc: 0.57 valid_loss: 0.65838 valid acc: 0.52
# [  45/1000] train_loss: 0.61089 train acc: 0.58 valid_loss: 0.69077 valid acc: 0.53
# [  50/1000] train_loss: 0.59964 train acc: 0.59 valid_loss: 0.71254 valid acc: 0.53
# [  55/1000] train_loss: 0.58587 train acc: 0.60 valid_loss: 0.75241 valid acc: 0.52
# [  60/1000] train_loss: 0.57820 train acc: 0.61 valid_loss: 0.70709 valid acc: 0.52
#
# 12/26 2021-06-07 training start
# [   5/1000] train_loss: 0.69184 train acc: 0.52 valid_loss: 0.69310 valid acc: 0.50
# [  10/1000] train_loss: 0.69010 train acc: 0.52 valid_loss: 0.69537 valid acc: 0.50
# [  15/1000] train_loss: 0.68838 train acc: 0.52 valid_loss: 0.69201 valid acc: 0.50
# [  20/1000] train_loss: 0.68440 train acc: 0.53 valid_loss: 0.70683 valid acc: 0.50
# [  25/1000] train_loss: 0.67889 train acc: 0.53 valid_loss: 0.70436 valid acc: 0.50
# [  30/1000] train_loss: 0.66705 train acc: 0.54 valid_loss: 0.71546 valid acc: 0.49
#
# 13/26 2021-06-21 training start
# [   5/1000] train_loss: 0.69210 train acc: 0.52 valid_loss: 0.69588 valid acc: 0.50
# [  10/1000] train_loss: 0.69181 train acc: 0.52 valid_loss: 0.69451 valid acc: 0.50
# [  15/1000] train_loss: 0.69153 train acc: 0.52 valid_loss: 0.69447 valid acc: 0.50
# [  20/1000] train_loss: 0.68963 train acc: 0.52 valid_loss: 0.69643 valid acc: 0.50
# [  25/1000] train_loss: 0.68491 train acc: 0.53 valid_loss: 0.69381 valid acc: 0.50
# [  30/1000] train_loss: 0.67501 train acc: 0.53 valid_loss: 0.70341 valid acc: 0.50
# [  35/1000] train_loss: 0.67119 train acc: 0.54 valid_loss: 0.70371 valid acc: 0.50
# [  40/1000] train_loss: 0.66034 train acc: 0.55 valid_loss: 0.71519 valid acc: 0.50
# [  45/1000] train_loss: 0.64729 train acc: 0.55 valid_loss: 0.71151 valid acc: 0.50
# [  50/1000] train_loss: 0.64276 train acc: 0.56 valid_loss: 0.70376 valid acc: 0.50
# [  55/1000] train_loss: 0.62251 train acc: 0.57 valid_loss: 0.73614 valid acc: 0.50
#
# 14/26 2021-07-05 training start
# [   5/1000] train_loss: 0.69250 train acc: 0.52 valid_loss: 0.69353 valid acc: 0.50
# [  10/1000] train_loss: 0.69124 train acc: 0.52 valid_loss: 0.69067 valid acc: 0.52
# [  15/1000] train_loss: 0.68802 train acc: 0.53 valid_loss: 0.68985 valid acc: 0.53
# [  20/1000] train_loss: 0.68132 train acc: 0.54 valid_loss: 0.68167 valid acc: 0.53
# [  25/1000] train_loss: 0.66613 train acc: 0.54 valid_loss: 0.68827 valid acc: 0.54
# [  30/1000] train_loss: 0.65533 train acc: 0.55 valid_loss: 0.70130 valid acc: 0.54
# [  35/1000] train_loss: 0.64169 train acc: 0.56 valid_loss: 0.70509 valid acc: 0.54
# [  40/1000] train_loss: 0.62428 train acc: 0.57 valid_loss: 0.73272 valid acc: 0.53
#
# 15/26 2021-07-19 training start
# [   5/1000] train_loss: 0.69328 train acc: 0.51 valid_loss: 0.69518 valid acc: 0.49
# [  10/1000] train_loss: 0.69073 train acc: 0.52 valid_loss: 0.69609 valid acc: 0.49
# [  15/1000] train_loss: 0.68902 train acc: 0.52 valid_loss: 0.69526 valid acc: 0.49
# [  20/1000] train_loss: 0.68771 train acc: 0.52 valid_loss: 0.69489 valid acc: 0.49
# [  25/1000] train_loss: 0.68703 train acc: 0.53 valid_loss: 0.69441 valid acc: 0.49
# [  30/1000] train_loss: 0.67783 train acc: 0.53 valid_loss: 0.68787 valid acc: 0.49
# [  35/1000] train_loss: 0.66913 train acc: 0.53 valid_loss: 0.70272 valid acc: 0.50
# [  40/1000] train_loss: 0.66570 train acc: 0.54 valid_loss: 0.69214 valid acc: 0.50
# [  45/1000] train_loss: 0.65646 train acc: 0.54 valid_loss: 0.70205 valid acc: 0.50
#
# 16/26 2021-08-02 training start
# [   5/1000] train_loss: 0.69244 train acc: 0.52 valid_loss: 0.69587 valid acc: 0.50
# [  10/1000] train_loss: 0.69193 train acc: 0.52 valid_loss: 0.69494 valid acc: 0.50
# [  15/1000] train_loss: 0.69131 train acc: 0.52 valid_loss: 0.69464 valid acc: 0.50
# [  20/1000] train_loss: 0.69183 train acc: 0.52 valid_loss: 0.69656 valid acc: 0.50
# [  25/1000] train_loss: 0.69133 train acc: 0.52 valid_loss: 0.69811 valid acc: 0.50
# [  30/1000] train_loss: 0.69095 train acc: 0.53 valid_loss: 0.69157 valid acc: 0.50
# [  35/1000] train_loss: 0.68826 train acc: 0.53 valid_loss: 0.70186 valid acc: 0.50
# [  40/1000] train_loss: 0.68437 train acc: 0.53 valid_loss: 0.69726 valid acc: 0.51
# [  45/1000] train_loss: 0.68163 train acc: 0.53 valid_loss: 0.67292 valid acc: 0.51
# [  50/1000] train_loss: 0.66953 train acc: 0.54 valid_loss: 0.69195 valid acc: 0.52
# [  55/1000] train_loss: 0.66249 train acc: 0.54 valid_loss: 0.71361 valid acc: 0.52
# [  60/1000] train_loss: 0.65313 train acc: 0.54 valid_loss: 0.69985 valid acc: 0.52
# [  65/1000] train_loss: 0.64284 train acc: 0.55 valid_loss: 0.71320 valid acc: 0.52
#
# 17/26 2021-08-16 training start
# [   5/1000] train_loss: 0.69147 train acc: 0.52 valid_loss: 0.69476 valid acc: 0.50
# [  10/1000] train_loss: 0.69157 train acc: 0.52 valid_loss: 0.69636 valid acc: 0.50
# [  15/1000] train_loss: 0.68731 train acc: 0.52 valid_loss: 0.69589 valid acc: 0.50
# [  20/1000] train_loss: 0.68144 train acc: 0.53 valid_loss: 0.69545 valid acc: 0.50
# [  25/1000] train_loss: 0.66520 train acc: 0.54 valid_loss: 0.68231 valid acc: 0.50
# [  30/1000] train_loss: 0.65359 train acc: 0.55 valid_loss: 0.69684 valid acc: 0.51
# [  35/1000] train_loss: 0.63968 train acc: 0.56 valid_loss: 0.71367 valid acc: 0.51
# [  40/1000] train_loss: 0.62616 train acc: 0.57 valid_loss: 0.70947 valid acc: 0.51
# [  45/1000] train_loss: 0.60761 train acc: 0.58 valid_loss: 0.69287 valid acc: 0.51
#
# 18/26 2021-08-30 training start
# [   5/1000] train_loss: 0.69204 train acc: 0.53 valid_loss: 0.69347 valid acc: 0.50
# [  10/1000] train_loss: 0.69081 train acc: 0.52 valid_loss: 0.69430 valid acc: 0.50
# [  15/1000] train_loss: 0.68765 train acc: 0.53 valid_loss: 0.69170 valid acc: 0.50
# [  20/1000] train_loss: 0.68178 train acc: 0.53 valid_loss: 0.70547 valid acc: 0.50
# [  25/1000] train_loss: 0.67050 train acc: 0.54 valid_loss: 0.71954 valid acc: 0.50
# [  30/1000] train_loss: 0.66073 train acc: 0.55 valid_loss: 0.72441 valid acc: 0.50
# [  35/1000] train_loss: 0.64449 train acc: 0.55 valid_loss: 0.71838 valid acc: 0.50
#
# 19/26 2021-09-13 training start
# [   5/1000] train_loss: 0.69131 train acc: 0.51 valid_loss: 0.70026 valid acc: 0.49
# [  10/1000] train_loss: 0.68979 train acc: 0.52 valid_loss: 0.69396 valid acc: 0.49
# [  15/1000] train_loss: 0.68537 train acc: 0.52 valid_loss: 0.69731 valid acc: 0.48
# [  20/1000] train_loss: 0.68131 train acc: 0.53 valid_loss: 0.70441 valid acc: 0.48
# [  25/1000] train_loss: 0.67700 train acc: 0.54 valid_loss: 0.68197 valid acc: 0.48
# [  30/1000] train_loss: 0.66529 train acc: 0.54 valid_loss: 0.68780 valid acc: 0.49
# [  35/1000] train_loss: 0.65607 train acc: 0.55 valid_loss: 0.72517 valid acc: 0.49
# [  40/1000] train_loss: 0.64823 train acc: 0.56 valid_loss: 0.69598 valid acc: 0.49
# [  45/1000] train_loss: 0.63125 train acc: 0.56 valid_loss: 0.70241 valid acc: 0.49
# [  50/1000] train_loss: 0.61794 train acc: 0.57 valid_loss: 0.75015 valid acc: 0.49
# [  55/1000] train_loss: 0.60064 train acc: 0.58 valid_loss: 0.77323 valid acc: 0.49
# [  60/1000] train_loss: 0.58957 train acc: 0.59 valid_loss: 0.69685 valid acc: 0.50
#
# 20/26 2021-09-27 training start
# [   5/1000] train_loss: 0.69076 train acc: 0.52 valid_loss: 0.69656 valid acc: 0.49
# [  10/1000] train_loss: 0.68896 train acc: 0.52 valid_loss: 0.69906 valid acc: 0.50
# [  15/1000] train_loss: 0.68295 train acc: 0.53 valid_loss: 0.69980 valid acc: 0.49
# [  20/1000] train_loss: 0.67394 train acc: 0.54 valid_loss: 0.70522 valid acc: 0.50
# [  25/1000] train_loss: 0.66461 train acc: 0.55 valid_loss: 0.71619 valid acc: 0.50
# [  30/1000] train_loss: 0.65225 train acc: 0.56 valid_loss: 0.73487 valid acc: 0.50
# [  35/1000] train_loss: 0.64069 train acc: 0.57 valid_loss: 0.76182 valid acc: 0.49
#
# 21/26 2021-10-11 training start
# [   5/1000] train_loss: 0.69125 train acc: 0.53 valid_loss: 0.69866 valid acc: 0.49
# [  10/1000] train_loss: 0.69037 train acc: 0.53 valid_loss: 0.69670 valid acc: 0.49
# [  15/1000] train_loss: 0.68651 train acc: 0.53 valid_loss: 0.69772 valid acc: 0.49
# [  20/1000] train_loss: 0.67775 train acc: 0.54 valid_loss: 0.69829 valid acc: 0.49
# [  25/1000] train_loss: 0.66342 train acc: 0.55 valid_loss: 0.71130 valid acc: 0.49
# [  30/1000] train_loss: 0.64625 train acc: 0.56 valid_loss: 0.67194 valid acc: 0.50
# [  35/1000] train_loss: 0.64085 train acc: 0.57 valid_loss: 0.69123 valid acc: 0.50
# [  40/1000] train_loss: 0.61785 train acc: 0.58 valid_loss: 0.71256 valid acc: 0.51
# [  45/1000] train_loss: 0.60389 train acc: 0.58 valid_loss: 0.67190 valid acc: 0.51
# [  50/1000] train_loss: 0.58742 train acc: 0.59 valid_loss: 0.64756 valid acc: 0.51
# [  55/1000] train_loss: 0.58116 train acc: 0.60 valid_loss: 0.75327 valid acc: 0.51
# [  60/1000] train_loss: 0.56722 train acc: 0.61 valid_loss: 0.81228 valid acc: 0.51
# [  65/1000] train_loss: 0.55426 train acc: 0.62 valid_loss: 0.77864 valid acc: 0.51
# [  70/1000] train_loss: 0.54616 train acc: 0.62 valid_loss: 0.85828 valid acc: 0.52
#
# 22/26 2021-10-25 training start
# [   5/1000] train_loss: 0.69178 train acc: 0.52 valid_loss: 0.67833 valid acc: 0.50
# [  10/1000] train_loss: 0.69172 train acc: 0.52 valid_loss: 0.67549 valid acc: 0.50
# [  15/1000] train_loss: 0.68879 train acc: 0.53 valid_loss: 0.68945 valid acc: 0.50
# [  20/1000] train_loss: 0.68413 train acc: 0.53 valid_loss: 0.71685 valid acc: 0.49
# [  25/1000] train_loss: 0.67393 train acc: 0.54 valid_loss: 0.60391 valid acc: 0.50
# [  30/1000] train_loss: 0.66016 train acc: 0.55 valid_loss: 0.68202 valid acc: 0.50
# [  35/1000] train_loss: 0.64364 train acc: 0.56 valid_loss: 0.71022 valid acc: 0.50
# [  40/1000] train_loss: 0.63264 train acc: 0.56 valid_loss: 0.71270 valid acc: 0.50
# [  45/1000] train_loss: 0.61590 train acc: 0.57 valid_loss: 0.81679 valid acc: 0.50
#
# 23/26 2021-11-08 training start
# [   5/1000] train_loss: 0.69290 train acc: 0.51 valid_loss: 0.69486 valid acc: 0.50
# [  10/1000] train_loss: 0.69209 train acc: 0.52 valid_loss: 0.70043 valid acc: 0.50
# [  15/1000] train_loss: 0.68940 train acc: 0.52 valid_loss: 0.69684 valid acc: 0.49
# [  20/1000] train_loss: 0.68507 train acc: 0.53 valid_loss: 0.69304 valid acc: 0.49
# [  25/1000] train_loss: 0.67562 train acc: 0.54 valid_loss: 0.70615 valid acc: 0.49
# [  30/1000] train_loss: 0.67088 train acc: 0.54 valid_loss: 0.69692 valid acc: 0.49
# [  35/1000] train_loss: 0.65954 train acc: 0.55 valid_loss: 0.67971 valid acc: 0.49
# [  40/1000] train_loss: 0.64325 train acc: 0.56 valid_loss: 0.69281 valid acc: 0.49
# [  45/1000] train_loss: 0.62508 train acc: 0.57 valid_loss: 0.73116 valid acc: 0.50
# [  50/1000] train_loss: 0.61265 train acc: 0.58 valid_loss: 0.78183 valid acc: 0.50
# [  55/1000] train_loss: 0.59905 train acc: 0.58 valid_loss: 0.75671 valid acc: 0.50
#
# 24/26 2021-11-22 training start
# [   5/1000] train_loss: 0.69241 train acc: 0.51 valid_loss: 0.69376 valid acc: 0.49
# [  10/1000] train_loss: 0.69070 train acc: 0.52 valid_loss: 0.69168 valid acc: 0.49
# [  15/1000] train_loss: 0.68746 train acc: 0.52 valid_loss: 0.69509 valid acc: 0.49
# [  20/1000] train_loss: 0.67726 train acc: 0.53 valid_loss: 0.69700 valid acc: 0.50
# [  25/1000] train_loss: 0.66396 train acc: 0.54 valid_loss: 0.70159 valid acc: 0.50
# [  30/1000] train_loss: 0.64596 train acc: 0.55 valid_loss: 0.69692 valid acc: 0.50
# [  35/1000] train_loss: 0.63359 train acc: 0.56 valid_loss: 0.71470 valid acc: 0.50
#
# 25/26 2021-12-06 training start
# [   5/1000] train_loss: 0.69234 train acc: 0.51 valid_loss: 0.69068 valid acc: 0.50
# [  10/1000] train_loss: 0.69223 train acc: 0.52 valid_loss: 0.69234 valid acc: 0.50
# [  15/1000] train_loss: 0.69263 train acc: 0.52 valid_loss: 0.69330 valid acc: 0.50
# [  20/1000] train_loss: 0.69219 train acc: 0.52 valid_loss: 0.68316 valid acc: 0.51
# [  25/1000] train_loss: 0.69016 train acc: 0.52 valid_loss: 0.68673 valid acc: 0.50
# [  30/1000] train_loss: 0.68834 train acc: 0.52 valid_loss: 0.68490 valid acc: 0.50
# [  35/1000] train_loss: 0.68219 train acc: 0.53 valid_loss: 0.70279 valid acc: 0.50
# [  40/1000] train_loss: 0.66959 train acc: 0.53 valid_loss: 0.69666 valid acc: 0.49
# [  45/1000] train_loss: 0.65973 train acc: 0.54 valid_loss: 0.69233 valid acc: 0.49
# [  50/1000] train_loss: 0.64408 train acc: 0.54 valid_loss: 0.72492 valid acc: 0.49
# [  55/1000] train_loss: 0.63406 train acc: 0.55 valid_loss: 0.72550 valid acc: 0.48
# [  60/1000] train_loss: 0.62136 train acc: 0.56 valid_loss: 0.75767 valid acc: 0.48
#
# 26/26 2021-12-20 training start
# [   5/1000] train_loss: 0.69242 train acc: 0.51 valid_loss: 0.70197 valid acc: 0.51
# [  10/1000] train_loss: 0.69163 train acc: 0.52 valid_loss: 0.69618 valid acc: 0.50
# [  15/1000] train_loss: 0.68794 train acc: 0.52 valid_loss: 0.69254 valid acc: 0.50
# [  20/1000] train_loss: 0.68180 train acc: 0.53 valid_loss: 0.70035 valid acc: 0.50
# [  25/1000] train_loss: 0.67430 train acc: 0.53 valid_loss: 0.71740 valid acc: 0.50
# [  30/1000] train_loss: 0.66231 train acc: 0.54 valid_loss: 0.72670 valid acc: 0.48
# [  35/1000] train_loss: 0.64323 train acc: 0.55 valid_loss: 0.74397 valid acc: 0.48
#
# 18 months
# Valid Acc : 53.28% Valid F1 : 50.35%
# Test Acc : 50.51% Test F1 : 47.44%
#
# Valid Confusion Matrix
# [[1335  455]
#  [1152  498]]
#
# Test Confusion Matrix
# [[1287  496]
#  [1210  454]]
#
# Wall time: 5min 7s
